# %%
import random
import numpy as np
import pandas as pd
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime

# %%
pip install citipy
# Out:
# Collecting citipy
#   Using cached citipy-0.0.5.tar.gz (557 kB)
# Collecting kdtree>=0.12
#   Using cached kdtree-0.16-py2.py3-none-any.whl (7.7 kB)
# Building wheels for collected packages: citipy
#   Building wheel for citipy (setup.py): started
#   Building wheel for citipy (setup.py): finished with status 'done'
#   Created wheel for citipy: filename=citipy-0.0.5-py3-none-any.whl size=559700 sha256=757276accb532712504398f1699fbe6801ac200392d598577355ee67f699ec6a
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\6d\df\5e\ad8eb9cc5ee7f4ba76865167c09f9a7edff405c669111d8353
# Successfully built citipy
# Installing collected packages: kdtree, citipy
# Successfully installed citipy-0.0.5 kdtree-0.16
# Note: you may need to restart the kernel to use updated packages.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longtitudes to a list
coordinates = list(lat_lngs)

# Create a list to hold the cities
cities = []

# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 751

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d846d71b8ceec80a3eeb9eb56927053d

# %%
# create an empty list to hold the weather daya.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind, 
                          "Current Description": city_description})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 16 | noumea
# Processing Record 2 of Set 16 | katsuura
# Processing Record 3 of Set 16 | husavik
# Processing Record 4 of Set 16 | ordynskoye
# Processing Record 5 of Set 16 | yellowknife
# Processing Record 6 of Set 16 | jamestown
# Processing Record 7 of Set 16 | meulaboh
# Processing Record 8 of Set 16 | koumac
# Processing Record 9 of Set 16 | setermoen
# Processing Record 10 of Set 16 | kem
# Processing Record 11 of Set 16 | bethel
# Processing Record 12 of Set 16 | punta arenas
# Processing Record 13 of Set 16 | samalaeulu
# City not found. Skipping...
# Processing Record 14 of Set 16 | portland
# Processing Record 15 of Set 16 | hilo
# Processing Record 16 of Set 16 | tasiilaq
# Processing Record 17 of Set 16 | pisco
# Processing Record 18 of Set 16 | saquarema
# Processing Record 19 of Set 16 | kapaa
# Processing Record 20 of Set 16 | mataura
# Processing Record 21 of Set 16 | rikitea
# Processing Record 22 of Set 16 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 16 | solwezi
# Processing Record 24 of Set 16 | riyadh
# Processing Record 25 of Set 16 | enna
# Processing Record 26 of Set 16 | hobart
# Processing Record 27 of Set 16 | san marcos
# Processing Record 28 of Set 16 | pacific grove
# Processing Record 29 of Set 16 | albany
# Processing Record 30 of Set 16 | vaini
# Processing Record 31 of Set 16 | chokurdakh
# Processing Record 32 of Set 16 | sorland
# Processing Record 33 of Set 16 | machala
# Processing Record 34 of Set 16 | cape town
# Processing Record 35 of Set 16 | ilulissat
# Processing Record 36 of Set 16 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 16 | smithers
# Processing Record 38 of Set 16 | new norfolk
# Processing Record 39 of Set 16 | iqaluit
# Processing Record 40 of Set 16 | hithadhoo
# Processing Record 41 of Set 16 | busselton
# Processing Record 42 of Set 16 | longyearbyen
# Processing Record 43 of Set 16 | lagos
# Processing Record 44 of Set 16 | qaanaaq
# Processing Record 45 of Set 16 | rocha
# Processing Record 46 of Set 16 | dunedin
# Processing Record 47 of Set 16 | tonantins
# Processing Record 48 of Set 16 | hasaki
# Processing Record 49 of Set 16 | carnarvon
# Processing Record 50 of Set 16 | airai
# Processing Record 1 of Set 17 | port-gentil
# Processing Record 2 of Set 17 | oil city
# Processing Record 3 of Set 17 | coquimbo
# Processing Record 4 of Set 17 | santa cruz
# Processing Record 5 of Set 17 | lompoc
# Processing Record 6 of Set 17 | hermanus
# Processing Record 7 of Set 17 | formoso do araguaia
# City not found. Skipping...
# Processing Record 8 of Set 17 | menongue
# Processing Record 9 of Set 17 | buraydah
# Processing Record 10 of Set 17 | norman wells
# Processing Record 11 of Set 17 | klaksvik
# Processing Record 12 of Set 17 | sabang
# Processing Record 13 of Set 17 | bluff
# Processing Record 14 of Set 17 | zhigansk
# Processing Record 15 of Set 17 | pokhara
# Processing Record 16 of Set 17 | awbari
# Processing Record 17 of Set 17 | coaraci
# Processing Record 18 of Set 17 | yerbogachen
# Processing Record 19 of Set 17 | severo-kurilsk
# Processing Record 20 of Set 17 | barbar
# City not found. Skipping...
# Processing Record 21 of Set 17 | ushuaia
# Processing Record 22 of Set 17 | cidreira
# Processing Record 23 of Set 17 | samarai
# Processing Record 24 of Set 17 | flin flon
# Processing Record 25 of Set 17 | cherskiy
# Processing Record 26 of Set 17 | pevek
# Processing Record 27 of Set 17 | tomatlan
# Processing Record 28 of Set 17 | khonuu
# City not found. Skipping...
# Processing Record 29 of Set 17 | victoria
# Processing Record 30 of Set 17 | aquin
# Processing Record 31 of Set 17 | wad rawah
# Processing Record 32 of Set 17 | jiayuguan
# Processing Record 33 of Set 17 | lebu
# Processing Record 34 of Set 17 | bom jesus da lapa
# Processing Record 35 of Set 17 | touho
# Processing Record 36 of Set 17 | tuktoyaktuk
# Processing Record 37 of Set 17 | marystown
# Processing Record 38 of Set 17 | kalianget
# Processing Record 39 of Set 17 | butaritari
# Processing Record 40 of Set 17 | nabire
# Processing Record 41 of Set 17 | puerto ayora
# Processing Record 42 of Set 17 | villazon
# Processing Record 43 of Set 17 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 17 | galiakot
# Processing Record 45 of Set 17 | blackwater
# Processing Record 46 of Set 17 | narsaq
# Processing Record 47 of Set 17 | caravelas
# Processing Record 48 of Set 17 | kodiak
# Processing Record 49 of Set 17 | laguna
# Processing Record 50 of Set 17 | egvekinot
# Processing Record 1 of Set 18 | nikolskoye
# Processing Record 2 of Set 18 | buin
# Processing Record 3 of Set 18 | ambodifototra
# City not found. Skipping...
# Processing Record 4 of Set 18 | khatanga
# Processing Record 5 of Set 18 | bathsheba
# Processing Record 6 of Set 18 | bocaranga
# City not found. Skipping...
# Processing Record 7 of Set 18 | guerrero negro
# Processing Record 8 of Set 18 | tiksi
# Processing Record 9 of Set 18 | east london
# Processing Record 10 of Set 18 | el badari
# City not found. Skipping...
# Processing Record 11 of Set 18 | lishan
# Processing Record 12 of Set 18 | clyde river
# Processing Record 13 of Set 18 | mahebourg
# Processing Record 14 of Set 18 | avarua
# Processing Record 15 of Set 18 | galiwinku
# City not found. Skipping...
# Processing Record 16 of Set 18 | kismayo
# Processing Record 17 of Set 18 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 18 | tekeli
# Processing Record 19 of Set 18 | hovd
# Processing Record 20 of Set 18 | wattegama
# Processing Record 21 of Set 18 | tondano
# Processing Record 22 of Set 18 | tual
# Processing Record 23 of Set 18 | barrow
# Processing Record 24 of Set 18 | kamenskoye
# City not found. Skipping...
# Processing Record 25 of Set 18 | ciras
# City not found. Skipping...
# Processing Record 26 of Set 18 | rawson
# Processing Record 27 of Set 18 | farsund
# Processing Record 28 of Set 18 | iskateley
# Processing Record 29 of Set 18 | huarmey
# Processing Record 30 of Set 18 | ponta do sol
# Processing Record 31 of Set 18 | porto seguro
# Processing Record 32 of Set 18 | hamilton
# Processing Record 33 of Set 18 | gerash
# Processing Record 34 of Set 18 | san cristobal
# Processing Record 35 of Set 18 | jacareacanga
# Processing Record 36 of Set 18 | tarakan
# Processing Record 37 of Set 18 | kavieng
# Processing Record 38 of Set 18 | boguchany
# Processing Record 39 of Set 18 | yining
# Processing Record 40 of Set 18 | hirara
# Processing Record 41 of Set 18 | seminole
# Processing Record 42 of Set 18 | kidal
# Processing Record 43 of Set 18 | balkhash
# Processing Record 44 of Set 18 | moroni
# Processing Record 45 of Set 18 | almaznyy
# Processing Record 46 of Set 18 | muzhi
# Processing Record 47 of Set 18 | ancud
# Processing Record 48 of Set 18 | jacala
# Processing Record 49 of Set 18 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 18 | melo
# Processing Record 1 of Set 19 | ornskoldsvik
# Processing Record 2 of Set 19 | alofi
# Processing Record 3 of Set 19 | kulu
# Processing Record 4 of Set 19 | whitehorse
# Processing Record 5 of Set 19 | fortuna
# Processing Record 6 of Set 19 | luganville
# Processing Record 7 of Set 19 | bredasdorp
# Processing Record 8 of Set 19 | pingxiang
# Processing Record 9 of Set 19 | tanjong malim
# City not found. Skipping...
# Processing Record 10 of Set 19 | at-bashi
# Processing Record 11 of Set 19 | cabo san lucas
# Processing Record 12 of Set 19 | cap malheureux
# Processing Record 13 of Set 19 | nanortalik
# Processing Record 14 of Set 19 | torbay
# Processing Record 15 of Set 19 | sur
# Processing Record 16 of Set 19 | umm lajj
# Processing Record 17 of Set 19 | mildura
# Processing Record 18 of Set 19 | aransas pass
# Processing Record 19 of Set 19 | arraial do cabo
# Processing Record 20 of Set 19 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 19 | souillac
# Processing Record 22 of Set 19 | mineiros
# Processing Record 23 of Set 19 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 19 | geraldton
# Processing Record 25 of Set 19 | ola
# Processing Record 26 of Set 19 | constitucion
# Processing Record 27 of Set 19 | yumen
# Processing Record 28 of Set 19 | minot
# Processing Record 29 of Set 19 | maldonado
# Processing Record 30 of Set 19 | dujuma
# City not found. Skipping...
# Processing Record 31 of Set 19 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 19 | traverse city
# Processing Record 33 of Set 19 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 19 | chapleau
# Processing Record 35 of Set 19 | chuy
# Processing Record 36 of Set 19 | sao filipe
# Processing Record 37 of Set 19 | yanam
# Processing Record 38 of Set 19 | port hedland
# Processing Record 39 of Set 19 | cairns
# Processing Record 40 of Set 19 | ulladulla
# Processing Record 41 of Set 19 | luderitz
# Processing Record 42 of Set 19 | gyanpur
# Processing Record 43 of Set 19 | krasnoselkup
# Processing Record 44 of Set 19 | izhma
# Processing Record 45 of Set 19 | saint george
# Processing Record 46 of Set 19 | kaitangata
# Processing Record 47 of Set 19 | tuatapere
# Processing Record 48 of Set 19 | saint-philippe
# Processing Record 49 of Set 19 | ust-uda
# Processing Record 50 of Set 19 | isangel
# Processing Record 1 of Set 20 | fort nelson
# Processing Record 2 of Set 20 | sulangan
# Processing Record 3 of Set 20 | jawhar
# Processing Record 4 of Set 20 | esperance
# Processing Record 5 of Set 20 | grand gaube
# Processing Record 6 of Set 20 | ulagan
# Processing Record 7 of Set 20 | saskylakh
# Processing Record 8 of Set 20 | wajid
# Processing Record 9 of Set 20 | tabiauea
# City not found. Skipping...
# Processing Record 10 of Set 20 | kaeo
# Processing Record 11 of Set 20 | grimshaw
# Processing Record 12 of Set 20 | show low
# Processing Record 13 of Set 20 | grand-santi
# Processing Record 14 of Set 20 | arlit
# Processing Record 15 of Set 20 | kununurra
# Processing Record 16 of Set 20 | takoradi
# Processing Record 17 of Set 20 | morki
# Processing Record 18 of Set 20 | santiago
# Processing Record 19 of Set 20 | chapais
# Processing Record 20 of Set 20 | bubaque
# Processing Record 21 of Set 20 | talnakh
# Processing Record 22 of Set 20 | choya
# Processing Record 23 of Set 20 | vytegra
# Processing Record 24 of Set 20 | georgetown
# Processing Record 25 of Set 20 | nha trang
# Processing Record 26 of Set 20 | vardo
# Processing Record 27 of Set 20 | toguchin
# Processing Record 28 of Set 20 | whitecourt
# Processing Record 29 of Set 20 | saldanha
# Processing Record 30 of Set 20 | teruel
# Processing Record 31 of Set 20 | kumba
# Processing Record 32 of Set 20 | haicheng
# Processing Record 33 of Set 20 | vredendal
# Processing Record 34 of Set 20 | the valley
# Processing Record 35 of Set 20 | severo-yeniseyskiy
# Processing Record 36 of Set 20 | barbastro
# Processing Record 37 of Set 20 | yar-sale
# Processing Record 38 of Set 20 | luwuk
# Processing Record 39 of Set 20 | tessalit
# Processing Record 40 of Set 20 | altay
# Processing Record 41 of Set 20 | lasa
# Processing Record 42 of Set 20 | belaya gora
# Processing Record 43 of Set 20 | thompson
# Processing Record 44 of Set 20 | quatre cocos
# Processing Record 45 of Set 20 | roma
# Processing Record 46 of Set 20 | boende
# Processing Record 47 of Set 20 | bethanien
# Processing Record 48 of Set 20 | san patricio
# Processing Record 49 of Set 20 | lagoa santa
# Processing Record 50 of Set 20 | isla vista
# Processing Record 1 of Set 21 | port lincoln
# Processing Record 2 of Set 21 | ballina
# Processing Record 3 of Set 21 | mancio lima
# Processing Record 4 of Set 21 | nova olimpia
# Processing Record 5 of Set 21 | rodnykove
# Processing Record 6 of Set 21 | ibotirama
# Processing Record 7 of Set 21 | mangla
# Processing Record 8 of Set 21 | kasamwa
# Processing Record 9 of Set 21 | saint-joseph
# Processing Record 10 of Set 21 | nago
# Processing Record 11 of Set 21 | bud
# Processing Record 12 of Set 21 | port alfred
# Processing Record 13 of Set 21 | taoudenni
# Processing Record 14 of Set 21 | hambantota
# Processing Record 15 of Set 21 | ocampo
# Processing Record 16 of Set 21 | dingle
# Processing Record 17 of Set 21 | ahipara
# Processing Record 18 of Set 21 | nanae
# Processing Record 19 of Set 21 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 21 | lata
# Processing Record 21 of Set 21 | oliver
# Processing Record 22 of Set 21 | cape coast
# Processing Record 23 of Set 21 | maneadero
# Processing Record 24 of Set 21 | coahuayana
# Processing Record 25 of Set 21 | juneau
# Processing Record 26 of Set 21 | amazar
# Processing Record 27 of Set 21 | leesburg
# Processing Record 28 of Set 21 | beringovskiy
# Processing Record 29 of Set 21 | korla
# Processing Record 30 of Set 21 | castro
# Processing Record 31 of Set 21 | rio grande
# Processing Record 32 of Set 21 | klasterec nad ohri
# Processing Record 33 of Set 21 | khasan
# Processing Record 34 of Set 21 | sao lourenco do sul
# Processing Record 35 of Set 21 | nelson bay
# Processing Record 36 of Set 21 | waingapu
# Processing Record 37 of Set 21 | dikson
# Processing Record 38 of Set 21 | hervey bay
# Processing Record 39 of Set 21 | codrington
# Processing Record 40 of Set 21 | chilapa
# Processing Record 41 of Set 21 | ilhabela
# Processing Record 42 of Set 21 | kamaishi
# Processing Record 43 of Set 21 | port elizabeth
# Processing Record 44 of Set 21 | west wendover
# Processing Record 45 of Set 21 | umm kaddadah
# Processing Record 46 of Set 21 | atuona
# Processing Record 47 of Set 21 | atlantic beach
# Processing Record 48 of Set 21 | hay river
# Processing Record 49 of Set 21 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 50 of Set 21 | roald
# Processing Record 1 of Set 22 | cascas
# Processing Record 2 of Set 22 | russell
# Processing Record 3 of Set 22 | cramlington
# Processing Record 4 of Set 22 | coihaique
# Processing Record 5 of Set 22 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 22 | lannion
# Processing Record 7 of Set 22 | lavrentiya
# Processing Record 8 of Set 22 | cayenne
# Processing Record 9 of Set 22 | botou
# Processing Record 10 of Set 22 | daru
# Processing Record 11 of Set 22 | la ronge
# Processing Record 12 of Set 22 | sakaiminato
# Processing Record 13 of Set 22 | guaimaro
# Processing Record 14 of Set 22 | baghdad
# Processing Record 15 of Set 22 | santa rosa
# Processing Record 16 of Set 22 | livingstonia
# Processing Record 17 of Set 22 | maniitsoq
# Processing Record 18 of Set 22 | broken hill
# Processing Record 19 of Set 22 | mirnyy
# Processing Record 20 of Set 22 | kungurtug
# Processing Record 21 of Set 22 | vostok
# Processing Record 22 of Set 22 | valparaiso
# Processing Record 23 of Set 22 | port blair
# Processing Record 24 of Set 22 | marovoay
# Processing Record 25 of Set 22 | smolensk
# Processing Record 26 of Set 22 | half moon bay
# Processing Record 27 of Set 22 | moiyabana
# City not found. Skipping...
# Processing Record 28 of Set 22 | price
# Processing Record 29 of Set 22 | zhengjiatun
# Processing Record 30 of Set 22 | loei
# Processing Record 31 of Set 22 | hun
# Processing Record 32 of Set 22 | ukiah
# Processing Record 33 of Set 22 | doha
# Processing Record 34 of Set 22 | mudyuga
# City not found. Skipping...
# Processing Record 35 of Set 22 | provideniya
# Processing Record 36 of Set 22 | idrija
# Processing Record 37 of Set 22 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 22 | sofiysk
# City not found. Skipping...
# Processing Record 39 of Set 22 | conneaut
# Processing Record 40 of Set 22 | bogorodskoye
# Processing Record 41 of Set 22 | sumbawa
# City not found. Skipping...
# Processing Record 42 of Set 22 | birjand
# Processing Record 43 of Set 22 | maebaru
# Processing Record 44 of Set 22 | gbarnga
# Processing Record 45 of Set 22 | phan thiet
# Processing Record 46 of Set 22 | agadir
# Processing Record 47 of Set 22 | rayon
# Processing Record 48 of Set 22 | mandaguacu
# Processing Record 49 of Set 22 | sibolga
# Processing Record 50 of Set 22 | whitianga
# Processing Record 1 of Set 23 | tucumcari
# Processing Record 2 of Set 23 | sterling
# Processing Record 3 of Set 23 | karratha
# Processing Record 4 of Set 23 | swellendam
# Processing Record 5 of Set 23 | anadyr
# Processing Record 6 of Set 23 | lagoa
# Processing Record 7 of Set 23 | moindou
# Processing Record 8 of Set 23 | ormara
# Processing Record 9 of Set 23 | vandoeuvre-les-nancy
# Processing Record 10 of Set 23 | marsa matruh
# Processing Record 11 of Set 23 | malinao
# Processing Record 12 of Set 23 | atar
# Processing Record 13 of Set 23 | lufilufi
# Processing Record 14 of Set 23 | la paz
# Processing Record 15 of Set 23 | araouane
# Processing Record 16 of Set 23 | baksanenok
# Processing Record 17 of Set 23 | volchikha
# Processing Record 18 of Set 23 | rio de janeiro
# Processing Record 19 of Set 23 | sinnamary
# Processing Record 20 of Set 23 | avera
# Processing Record 21 of Set 23 | laem sing
# Processing Record 22 of Set 23 | sampit
# Processing Record 23 of Set 23 | tommot
# Processing Record 24 of Set 23 | hualmay
# Processing Record 25 of Set 23 | pasighat
# Processing Record 26 of Set 23 | antsirabe
# Processing Record 27 of Set 23 | paamiut
# Processing Record 28 of Set 23 | rawannawi
# City not found. Skipping...
# Processing Record 29 of Set 23 | francisco morato
# Processing Record 30 of Set 23 | mogocha
# Processing Record 31 of Set 23 | mackay
# Processing Record 32 of Set 23 | plettenberg bay
# Processing Record 33 of Set 23 | grenville
# Processing Record 34 of Set 23 | salalah
# Processing Record 35 of Set 23 | boa vista
# Processing Record 36 of Set 23 | suruc
# Processing Record 37 of Set 23 | dahuk
# Processing Record 38 of Set 23 | skjervoy
# Processing Record 39 of Set 23 | skibbereen
# Processing Record 40 of Set 23 | sao felix do xingu
# Processing Record 41 of Set 23 | mount gambier
# Processing Record 42 of Set 23 | sangar
# Processing Record 43 of Set 23 | rio gallegos
# Processing Record 44 of Set 23 | turhal
# Processing Record 45 of Set 23 | oum hadjer
# Processing Record 46 of Set 23 | mustasaari
# Processing Record 47 of Set 23 | kruisfontein
# Processing Record 48 of Set 23 | mango
# Processing Record 49 of Set 23 | halalo
# City not found. Skipping...
# Processing Record 50 of Set 23 | berlevag
# Processing Record 1 of Set 24 | high level
# Processing Record 2 of Set 24 | zhuzhou
# Processing Record 3 of Set 24 | zhanatas
# City not found. Skipping...
# Processing Record 4 of Set 24 | horsham
# Processing Record 5 of Set 24 | palmer
# Processing Record 6 of Set 24 | atsiki
# City not found. Skipping...
# Processing Record 7 of Set 24 | farafangana
# Processing Record 8 of Set 24 | saryg-sep
# Processing Record 9 of Set 24 | fengzhen
# Processing Record 10 of Set 24 | port macquarie
# Processing Record 11 of Set 24 | tabas
# Processing Record 12 of Set 24 | aklavik
# Processing Record 13 of Set 24 | shimoda
# Processing Record 14 of Set 24 | bosaso
# Processing Record 15 of Set 24 | ondorhaan
# City not found. Skipping...
# Processing Record 16 of Set 24 | kotka
# Processing Record 17 of Set 24 | harper
# Processing Record 18 of Set 24 | antequera
# Processing Record 19 of Set 24 | srednekolymsk
# Processing Record 20 of Set 24 | urengoy
# Processing Record 21 of Set 24 | sinjar
# Processing Record 22 of Set 24 | aneho
# Processing Record 23 of Set 24 | sambata
# City not found. Skipping...
# Processing Record 24 of Set 24 | port maria
# Processing Record 25 of Set 24 | brasilia de minas
# Processing Record 26 of Set 24 | raudeberg
# Processing Record 27 of Set 24 | inirida
# Processing Record 28 of Set 24 | wysokie mazowieckie
# Processing Record 29 of Set 24 | groton
# Processing Record 30 of Set 24 | hofn
# Processing Record 31 of Set 24 | neuquen
# Processing Record 32 of Set 24 | naze
# Processing Record 33 of Set 24 | vila franca do campo
# Processing Record 34 of Set 24 | kutum
# Processing Record 35 of Set 24 | north myrtle beach
# Processing Record 36 of Set 24 | san ramon
# Processing Record 37 of Set 24 | muros
# Processing Record 38 of Set 24 | cantapoy
# Processing Record 39 of Set 24 | balkanabat
# Processing Record 40 of Set 24 | sechura
# Processing Record 41 of Set 24 | dibaya
# City not found. Skipping...
# Processing Record 42 of Set 24 | sovetskiy
# Processing Record 43 of Set 24 | derzhavinsk
# Processing Record 44 of Set 24 | gondanglegi
# Processing Record 45 of Set 24 | alice springs
# Processing Record 46 of Set 24 | pendleton
# Processing Record 47 of Set 24 | chenzhou
# Processing Record 48 of Set 24 | namibe
# Processing Record 49 of Set 24 | los llanos de aridane
# Processing Record 50 of Set 24 | pine bluff
# Processing Record 1 of Set 25 | shagonar
# Processing Record 2 of Set 25 | komsomolskiy
# Processing Record 3 of Set 25 | morant bay
# Processing Record 4 of Set 25 | shingu
# Processing Record 5 of Set 25 | carutapera
# Processing Record 6 of Set 25 | mayumba
# Processing Record 7 of Set 25 | katav-ivanovsk
# Processing Record 8 of Set 25 | abapo
# Processing Record 9 of Set 25 | asau
# Processing Record 10 of Set 25 | bambous virieux
# Processing Record 11 of Set 25 | gushikawa
# Processing Record 12 of Set 25 | marshall
# Processing Record 13 of Set 25 | bac lieu
# Processing Record 14 of Set 25 | byron bay
# Processing Record 15 of Set 25 | port hardy
# Processing Record 16 of Set 25 | benghazi
# Processing Record 17 of Set 25 | brae
# Processing Record 18 of Set 25 | payson
# Processing Record 19 of Set 25 | makubetsu
# Processing Record 20 of Set 25 | sorvag
# City not found. Skipping...
# Processing Record 21 of Set 25 | ilula
# Processing Record 22 of Set 25 | itoman
# Processing Record 23 of Set 25 | kadykchan
# City not found. Skipping...
# Processing Record 24 of Set 25 | henties bay
# Processing Record 25 of Set 25 | mar del plata
# Processing Record 26 of Set 25 | baykit
# Processing Record 27 of Set 25 | vallenar
# Processing Record 28 of Set 25 | eldikan
# City not found. Skipping...
# Processing Record 29 of Set 25 | upernavik
# Processing Record 30 of Set 25 | uribia
# Processing Record 31 of Set 25 | iralaya
# Processing Record 32 of Set 25 | boyolangu
# Processing Record 33 of Set 25 | camocim
# Processing Record 34 of Set 25 | ribeira grande
# Processing Record 35 of Set 25 | manzanillo
# Processing Record 36 of Set 25 | el tigre
# Processing Record 37 of Set 25 | parambu
# Processing Record 38 of Set 25 | nome
# Processing Record 39 of Set 25 | babanusah
# City not found. Skipping...
# Processing Record 40 of Set 25 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 25 | mitsamiouli
# Processing Record 42 of Set 25 | khromtau
# Processing Record 43 of Set 25 | maltahohe
# Processing Record 44 of Set 25 | lokosovo
# Processing Record 45 of Set 25 | cooma
# Processing Record 46 of Set 25 | ustye
# Processing Record 47 of Set 25 | freetown
# Processing Record 48 of Set 25 | syasstroy
# Processing Record 49 of Set 25 | uray
# Processing Record 50 of Set 25 | belmonte
# Processing Record 1 of Set 26 | namatanai
# Processing Record 2 of Set 26 | tagusao
# Processing Record 3 of Set 26 | vung tau
# Processing Record 4 of Set 26 | murdochville
# Processing Record 5 of Set 26 | dolbeau
# City not found. Skipping...
# Processing Record 6 of Set 26 | bowen
# Processing Record 7 of Set 26 | las palmas
# Processing Record 8 of Set 26 | luanda
# Processing Record 9 of Set 26 | fare
# Processing Record 10 of Set 26 | tigre
# Processing Record 11 of Set 26 | sambava
# Processing Record 12 of Set 26 | taltal
# Processing Record 13 of Set 26 | pese
# Processing Record 14 of Set 26 | tarudant
# City not found. Skipping...
# Processing Record 15 of Set 26 | fergus falls
# Processing Record 16 of Set 26 | hays
# Processing Record 17 of Set 26 | bonthe
# Processing Record 18 of Set 26 | pangody
# Processing Record 19 of Set 26 | vidim
# Processing Record 20 of Set 26 | naliya
# Processing Record 21 of Set 26 | bargal
# City not found. Skipping...
# Processing Record 22 of Set 26 | flinders
# Processing Record 23 of Set 26 | chernitsyno
# Processing Record 24 of Set 26 | poplar bluff
# Processing Record 25 of Set 26 | stary sacz
# Processing Record 26 of Set 26 | muyezerskiy
# Processing Record 27 of Set 26 | chau doc
# Processing Record 28 of Set 26 | north bend
# Processing Record 29 of Set 26 | bushehr
# Processing Record 30 of Set 26 | lapua
# Processing Record 31 of Set 26 | gurupi
# Processing Record 32 of Set 26 | labuhan
# Processing Record 33 of Set 26 | umzimvubu
# City not found. Skipping...
# Processing Record 34 of Set 26 | ekibastuz
# Processing Record 35 of Set 26 | broome
# Processing Record 36 of Set 26 | kichera
# Processing Record 37 of Set 26 | shieli
# Processing Record 38 of Set 26 | bengkulu
# Processing Record 39 of Set 26 | hit
# Processing Record 40 of Set 26 | sal rei
# Processing Record 41 of Set 26 | enugu
# Processing Record 42 of Set 26 | shalinskoye
# Processing Record 43 of Set 26 | kotaparh
# Processing Record 44 of Set 26 | chenghai
# Processing Record 45 of Set 26 | hauterive
# Processing Record 46 of Set 26 | ostrovnoy
# Processing Record 47 of Set 26 | sikasso
# Processing Record 48 of Set 26 | grants
# Processing Record 49 of Set 26 | barra do corda
# Processing Record 50 of Set 26 | ucluelet
# Processing Record 1 of Set 27 | sarangani
# Processing Record 2 of Set 27 | lorengau
# Processing Record 3 of Set 27 | filimonovo
# Processing Record 4 of Set 27 | thoen
# Processing Record 5 of Set 27 | sidi bu zayd
# City not found. Skipping...
# Processing Record 6 of Set 27 | stokmarknes
# Processing Record 7 of Set 27 | kailua
# Processing Record 8 of Set 27 | palu
# Processing Record 9 of Set 27 | touros
# Processing Record 10 of Set 27 | teahupoo
# Processing Record 11 of Set 27 | zhenlai
# Processing Record 12 of Set 27 | eyl
# Processing Record 13 of Set 27 | sabha
# Processing Record 14 of Set 27 | fairbanks
# Processing Record 15 of Set 27 | hami
# Processing Record 16 of Set 27 | faanui
# Processing Record 17 of Set 27 | wanning
# Processing Record 18 of Set 27 | birao
# Processing Record 19 of Set 27 | monrovia
# Processing Record 20 of Set 27 | huanan
# Processing Record 21 of Set 27 | mapiripan
# Processing Record 22 of Set 27 | mrirt
# City not found. Skipping...
# Processing Record 23 of Set 27 | berbera
# Processing Record 24 of Set 27 | bridlington
# Processing Record 25 of Set 27 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 27 | saint-augustin
# Processing Record 27 of Set 27 | pundaguitan
# Processing Record 28 of Set 27 | mendi
# Processing Record 29 of Set 27 | manokwari
# Processing Record 30 of Set 27 | novobirilyussy
# Processing Record 31 of Set 27 | ngukurr
# City not found. Skipping...
# Processing Record 32 of Set 27 | azuaga
# Processing Record 33 of Set 27 | kayerkan
# Processing Record 34 of Set 27 | dzhusaly
# City not found. Skipping...
# Processing Record 35 of Set 27 | itarema
# Processing Record 36 of Set 27 | richmond hill
# Processing Record 37 of Set 27 | sinkat
# City not found. Skipping...
# Processing Record 38 of Set 27 | mixtequilla
# City not found. Skipping...
# Processing Record 39 of Set 27 | katangli
# Processing Record 40 of Set 27 | trogir
# Processing Record 41 of Set 27 | pangnirtung
# Processing Record 42 of Set 27 | jieshi
# Processing Record 43 of Set 27 | borkenes
# Processing Record 44 of Set 27 | inderborskiy
# City not found. Skipping...
# Processing Record 45 of Set 27 | kahului
# Processing Record 46 of Set 27 | atambua
# Processing Record 47 of Set 27 | manta
# Processing Record 48 of Set 27 | mettur
# Processing Record 49 of Set 27 | pachperwa
# Processing Record 50 of Set 27 | iguape
# Processing Record 1 of Set 28 | isiro
# Processing Record 2 of Set 28 | talaya
# Processing Record 3 of Set 28 | pascagoula
# Processing Record 4 of Set 28 | maine-soroa
# Processing Record 5 of Set 28 | rock sound
# Processing Record 6 of Set 28 | sciacca
# Processing Record 7 of Set 28 | louisbourg
# City not found. Skipping...
# Processing Record 8 of Set 28 | mizpe ramon
# City not found. Skipping...
# Processing Record 9 of Set 28 | portel
# Processing Record 10 of Set 28 | caucaia
# Processing Record 11 of Set 28 | alexandria
# Processing Record 12 of Set 28 | cabra
# Processing Record 13 of Set 28 | fallon
# Processing Record 14 of Set 28 | helena
# Processing Record 15 of Set 28 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 28 | chopda
# Processing Record 17 of Set 28 | meyungs
# City not found. Skipping...
# Processing Record 18 of Set 28 | gravdal
# Processing Record 19 of Set 28 | gazimagusa
# City not found. Skipping...
# Processing Record 20 of Set 28 | bilibino
# Processing Record 21 of Set 28 | jining
# Processing Record 22 of Set 28 | divnomorskoye
# Processing Record 23 of Set 28 | tres lagoas
# Processing Record 24 of Set 28 | hermosillo
# Processing Record 25 of Set 28 | sitka
# Processing Record 26 of Set 28 | maiduguri
# Processing Record 27 of Set 28 | itaqui
# Processing Record 28 of Set 28 | hedaru
# Processing Record 29 of Set 28 | puerto narino
# Processing Record 30 of Set 28 | fayaoue
# Processing Record 31 of Set 28 | jumla
# Processing Record 32 of Set 28 | sibu
# Processing Record 33 of Set 28 | frutigen
# Processing Record 34 of Set 28 | abatskoye
# Processing Record 35 of Set 28 | kortkeros
# Processing Record 36 of Set 28 | quilmana
# Processing Record 37 of Set 28 | cockburn town
# Processing Record 38 of Set 28 | oussouye
# Processing Record 39 of Set 28 | podeni
# Processing Record 40 of Set 28 | ambilobe
# Processing Record 41 of Set 28 | skagastrond
# City not found. Skipping...
# Processing Record 42 of Set 28 | pouebo
# Processing Record 43 of Set 28 | aykhal
# Processing Record 44 of Set 28 | balezino
# Processing Record 45 of Set 28 | gorele
# Processing Record 46 of Set 28 | kipushi
# Processing Record 47 of Set 28 | chara
# Processing Record 48 of Set 28 | namtsy
# Processing Record 49 of Set 28 | saint-louis
# Processing Record 50 of Set 28 | hobyo
# Processing Record 1 of Set 29 | kieta
# Processing Record 2 of Set 29 | manzil tamim
# City not found. Skipping...
# Processing Record 3 of Set 29 | hirado
# Processing Record 4 of Set 29 | havelock
# Processing Record 5 of Set 29 | sicamous
# Processing Record 6 of Set 29 | santiago del estero
# Processing Record 7 of Set 29 | mwene-ditu
# Processing Record 8 of Set 29 | saint anthony
# Processing Record 9 of Set 29 | galesong
# Processing Record 10 of Set 29 | marawi
# Processing Record 11 of Set 29 | staryy nadym
# Processing Record 12 of Set 29 | college
# Processing Record 13 of Set 29 | buala
# Processing Record 14 of Set 29 | duncan
# Processing Record 15 of Set 29 | kiama
# Processing Record 16 of Set 29 | havoysund
# Processing Record 17 of Set 29 | faya
# Processing Record 18 of Set 29 | maceio
# Processing Record 19 of Set 29 | axim
# Processing Record 20 of Set 29 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 29 | tongliao
# Processing Record 22 of Set 29 | ayorou
# Processing Record 23 of Set 29 | pasco
# Processing Record 24 of Set 29 | salcedo
# Processing Record 25 of Set 29 | saint-francois
# Processing Record 26 of Set 29 | forio
# Processing Record 27 of Set 29 | bom jesus
# Processing Record 28 of Set 29 | bur gabo
# City not found. Skipping...
# Processing Record 29 of Set 29 | changqing
# Processing Record 30 of Set 29 | pauini
# Processing Record 31 of Set 29 | alta floresta
# Processing Record 32 of Set 29 | abilene
# Processing Record 33 of Set 29 | abhar
# Processing Record 34 of Set 29 | progreso
# Processing Record 35 of Set 29 | gateshead
# Processing Record 36 of Set 29 | saint-georges
# Processing Record 37 of Set 29 | jalu
# Processing Record 38 of Set 29 | tilichiki
# Processing Record 39 of Set 29 | grosuplje
# Processing Record 40 of Set 29 | lvov
# Processing Record 41 of Set 29 | vilyuysk
# Processing Record 42 of Set 29 | zhaotong
# Processing Record 43 of Set 29 | dossor
# Processing Record 44 of Set 29 | nouadhibou
# Processing Record 45 of Set 29 | moranbah
# Processing Record 46 of Set 29 | char bhadrasan
# Processing Record 47 of Set 29 | santa cruz de tenerife
# Processing Record 48 of Set 29 | haines junction
# Processing Record 49 of Set 29 | tete
# Processing Record 50 of Set 29 | gamba
# Processing Record 1 of Set 30 | toppenish
# Processing Record 2 of Set 30 | jaggayyapeta
# Processing Record 3 of Set 30 | agadez
# Processing Record 4 of Set 30 | burica
# City not found. Skipping...
# Processing Record 5 of Set 30 | soyo
# Processing Record 6 of Set 30 | imbituba
# Processing Record 7 of Set 30 | andevoranto
# City not found. Skipping...
# Processing Record 8 of Set 30 | karambakkudi
# Processing Record 9 of Set 30 | mentok
# City not found. Skipping...
# Processing Record 10 of Set 30 | tanshui
# City not found. Skipping...
# Processing Record 11 of Set 30 | costinesti
# Processing Record 12 of Set 30 | macon
# Processing Record 13 of Set 30 | comodoro rivadavia
# Processing Record 14 of Set 30 | cody
# Processing Record 15 of Set 30 | tuggurt
# City not found. Skipping...
# Processing Record 16 of Set 30 | dalbeattie
# Processing Record 17 of Set 30 | grand centre
# City not found. Skipping...
# Processing Record 18 of Set 30 | olafsvik
# Processing Record 19 of Set 30 | brigantine
# Processing Record 20 of Set 30 | kharitonovo
# Processing Record 21 of Set 30 | juliaca
# Processing Record 22 of Set 30 | linxia
# Processing Record 23 of Set 30 | amet
# Processing Record 24 of Set 30 | lososina
# Processing Record 25 of Set 30 | warqla
# City not found. Skipping...
# Processing Record 26 of Set 30 | san jose
# Processing Record 27 of Set 30 | mnogovershinnyy
# Processing Record 28 of Set 30 | requena
# Processing Record 29 of Set 30 | helong
# Processing Record 30 of Set 30 | padang
# Processing Record 31 of Set 30 | kurilsk
# Processing Record 32 of Set 30 | tonekabon
# Processing Record 33 of Set 30 | methoni
# Processing Record 34 of Set 30 | calama
# Processing Record 35 of Set 30 | baruun-urt
# Processing Record 36 of Set 30 | gat
# Processing Record 37 of Set 30 | maningrida
# Processing Record 38 of Set 30 | dublin
# Processing Record 39 of Set 30 | kabanjahe
# Processing Record 40 of Set 30 | tulagi
# Processing Record 41 of Set 30 | morehead
# Processing Record 42 of Set 30 | gorom-gorom
# Processing Record 43 of Set 30 | inhambane
# Processing Record 44 of Set 30 | barra
# Processing Record 45 of Set 30 | cap-aux-meules
# Processing Record 46 of Set 30 | omboue
# Processing Record 47 of Set 30 | udachnyy
# Processing Record 48 of Set 30 | tura
# Processing Record 49 of Set 30 | mattru
# Processing Record 50 of Set 30 | phalombe
# Processing Record 1 of Set 31 | banjar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 681

# %%
# Convert the array of dictionaries to a DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Noumea      NC -22.2763  166.4572     84.18        99          63
# 1     Katsuura      JP  35.1333  140.3000     48.18        81          95
# 2      Husavik      IS  66.0449  -17.3389     42.71        89         100
# 3   Ordynskoye      RU  54.3656   81.8994      2.80        98          70
# 4  Yellowknife      CA  62.4560 -114.3525      2.41        58           0
# 5    Jamestown      US  42.0970  -79.2353     45.72        40          75
# 6     Meulaboh      ID   4.1363   96.1285     77.63        85         100
# 7       Koumac      NC -20.5667  164.2833     81.86        74         100
# 8    Setermoen      NO  68.8610   18.3486     33.44        82         100
# 9          Kem      RU  64.9555   34.5793     32.18        92         100
#
#    Wind Speed Current Description
# 0        7.87       broken clouds
# 1        9.40     overcast clouds
# 2       25.08     overcast clouds
# 3        8.21       broken clouds
# 4        2.30           clear sky
# 5        8.05       broken clouds
# 6        4.70     overcast clouds
# 7        4.68     overcast clouds
# 8        3.00     overcast clouds
# 9        8.43     overcast clouds

# %%
city_data_df.to_csv("WeatherPy_Database.csv")
